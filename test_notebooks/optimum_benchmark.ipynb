# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from optimum_benchmark import Benchmark, BenchmarkConfig, TorchrunConfig, InferenceConfig, PyTorchConfig
from optimum_benchmark.logging_utils import setup_logging

def run_benchmark():
    model_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
    backend = "pytorch"

    # Setup logging with INFO level
    setup_logging(level="INFO")
    
    # Configure the launcher for a single GPU (nproc_per_node=1)
    launcher_config = TorchrunConfig(nproc_per_node=1)
    
    # Configure the inference scenario to measure latency and memory,
    # and set the input shape for the sequence length
    scenario_config = InferenceConfig(latency=True, memory=True, input_shapes={"sequence_length": 128})
    
    # Configure the backend with model details and GPU device settings.
    # The no_weights=True flag can be used if you don't need to load model weights (for a dry run, etc.)
    backend_config = PyTorchConfig(model=model_name, device="cuda", device_ids="0", no_weights=True)
    
    # Define the overall benchmark configuration
    benchmark_config = BenchmarkConfig(
        name=f"{backend}_{model_name}",
        scenario=scenario_config,
        launcher=launcher_config,
        backend=backend_config,
    )
    
    # Launch the benchmark and convert the report to a dictionary
    benchmark_report = Benchmark.launch(benchmark_config)
    benchmark_results = benchmark_report.to_dict()
    
    return benchmark_results

if __name__ == "__main__":
    results = run_benchmark()
    print("Benchmark Results:")
    print(results)
# Out:
# [2025-03-14 11:07:11,588][backend][INFO] - CUDA_VISIBLE_DEVICES was set to 0.
# [2025-03-14 11:07:11,816][torchrun][INFO] - Allocated torchrun launcher
# [RANK-PROCESS-0][2025-03-14 11:07:28,561][torchrun][INFO] - 	+ Setting torch.distributed cuda device to 0
# [RANK-PROCESS-0][2025-03-14 11:07:28,614][torchrun][INFO] - 	+ Initializing torch.distributed process group
# [RANK-PROCESS-0][2025-03-14 11:07:28,668][datasets][INFO] - PyTorch version 2.1.2 available.
# [RANK-PROCESS-0][2025-03-14 11:07:30,074][pytorch][INFO] - Allocating pytorch backend
# [RANK-PROCESS-0][2025-03-14 11:07:30,074][pytorch][INFO] - 	+ Seeding backend with 42
# [RANK-PROCESS-0][2025-03-14 11:07:30,075][pytorch][INFO] - 	+ Benchmarking a Transformers model
# [RANK-PROCESS-0][2025-03-14 11:07:31,286][inference][INFO] - Allocating inference scenario
# [RANK-PROCESS-0][2025-03-14 11:07:31,287][inference][INFO] - 	+ Updating Text Generation kwargs with default values
# [RANK-PROCESS-0][2025-03-14 11:07:31,287][inference][INFO] - 	+ Initializing Text Generation report
# [RANK-PROCESS-0][2025-03-14 11:07:31,289][inference][INFO] - 	+ Initializing Latency tracker
# [RANK-PROCESS-0][2025-03-14 11:07:31,289][latency][INFO] - 		+ Tracking latency using Pytorch CUDA events
# [RANK-PROCESS-0][2025-03-14 11:07:31,289][inference][INFO] - 	+ Initializing Per-Token Latency tracker
# [RANK-PROCESS-0][2025-03-14 11:07:31,289][latency][INFO] - 		+ Tracking latency using Pytorch CUDA events
# [RANK-PROCESS-0][2025-03-14 11:07:31,289][inference][INFO] - 	+ Initializing Memory tracker
# [RANK-PROCESS-0][2025-03-14 11:07:31,290][memory][INFO] - 		+ Tracking RAM memory of process 3004524
# [RANK-PROCESS-0][2025-03-14 11:07:31,290][memory][INFO] - 		+ Tracking GPU memory of devices [0]
# [RANK-PROCESS-0][2025-03-14 11:07:31,290][memory][INFO] - 		+ Tracking Allocated/Reserved memory of 1 Pytorch CUDA devices
# [RANK-PROCESS-0][2025-03-14 11:07:31,291][inference][INFO] - 	+ Generating inputs for task text-generation
# [RANK-PROCESS-0][2025-03-14 11:07:31,321][inference][INFO] - 	+ Running model loading tracking
# [RANK-PROCESS-0][2025-03-14 11:07:47,132][pytorch][INFO] - 	+ Creating backend temporary directory
# [RANK-PROCESS-0][2025-03-14 11:07:47,133][pytorch][INFO] - 	+ Creating no weights model
# [RANK-PROCESS-0][2025-03-14 11:07:47,133][pytorch][INFO] - 	+ Creating no weights model directory
# [RANK-PROCESS-0][2025-03-14 11:07:47,134][pytorch][INFO] - 	+ Creating no weights model state dict
# [RANK-PROCESS-0][2025-03-14 11:07:47,136][pytorch][INFO] - 	+ Saving no weights model safetensors
# [RANK-PROCESS-0][2025-03-14 11:07:47,141][pytorch][INFO] - 	+ Saving no weights model pretrained config
# [RANK-PROCESS-0][2025-03-14 11:07:47,149][pytorch][INFO] - 	+ Loading model with random weights
# [RANK-PROCESS-0][2025-03-14 11:07:47,151][pytorch][INFO] - 	+ Loading Transformers model using device context manager for fast initialization
# [RANK-PROCESS-0][2025-03-14 11:07:47,565][pytorch][INFO] - 	+ Enabling eval mode
# [RANK-PROCESS-0][2025-03-14 11:07:47,568][pytorch][INFO] - 	+ Cleaning up backend temporary directory
# [RANK-PROCESS-0][2025-03-14 11:07:47,588][inference][INFO] - 	+ Preparing inputs for backend pytorch
# [RANK-PROCESS-0][2025-03-14 11:07:47,698][inference][INFO] - 	+ Warming up backend for Text Generation
# [RANK-PROCESS-0][2025-03-14 11:07:53,191][inference][INFO] - 	+ Running Per-Token Text Generation latency tracking
# [RANK-PROCESS-0][2025-03-14 11:08:24,548][inference][INFO] - 	+ Running Text Generation memory tracking
# [RANK-PROCESS-0][2025-03-14 11:09:00,978][torchrun][INFO] - 	+ Benchmark completed successfully
# [RANK-PROCESS-0][2025-03-14 11:09:00,994][torchrun][INFO] - 	+ Destroying torch.distributed process group
# [RANK-PROCESS-0][2025-03-14 11:09:00,995][torchrun][INFO] - 	+ Exiting rank process
# [ISOLATED-PROCESS][2025-03-14 11:09:24,151][torchrun][INFO] - 	+ Sending outputs to main process
# [ISOLATED-PROCESS][2025-03-14 11:09:24,153][torchrun][INFO] - 	+ Exiting isolated process
# [2025-03-14 11:09:26,635][torchrun][INFO] - 	+ Received report from rank process [0]
# [2025-03-14 11:09:26,660][torchrun][INFO] - 	+ Aggregating reports from all rank processes
# [2025-03-14 11:09:26,734][report][INFO] - + load_model:
# [2025-03-14 11:09:26,736][report][INFO] - 	+ memory:
# [2025-03-14 11:09:26,739][report][INFO] - 		+ max_ram: 842.00 (MB)
# [2025-03-14 11:09:26,740][report][INFO] - 		+ max_global_vram: 14725.22 (MB)
# [2025-03-14 11:09:26,741][report][INFO] - 		+ max_process_vram: 4915.72 (MB)
# [2025-03-14 11:09:26,743][report][INFO] - 		+ max_reserved: 4401.92 (MB)
# [2025-03-14 11:09:26,744][report][INFO] - 		+ max_allocated: 4400.20 (MB)
# [2025-03-14 11:09:26,745][report][INFO] - 	+ latency:
# [2025-03-14 11:09:26,746][report][INFO] - 		+ count: 1
# [2025-03-14 11:09:26,747][report][INFO] - 		+ total: 0.436764 (s)
# [2025-03-14 11:09:26,749][report][INFO] - 		+ mean: 0.436764 (s)
# [2025-03-14 11:09:26,749][report][INFO] - 		+ p50: 0.436764 (s)
# [2025-03-14 11:09:26,750][report][INFO] - 		+ p90: 0.436764 (s)
# [2025-03-14 11:09:26,750][report][INFO] - 		+ p95: 0.436764 (s)
# [2025-03-14 11:09:26,751][report][INFO] - 		+ p99: 0.436764 (s)
# [2025-03-14 11:09:26,752][report][INFO] - 		+ stdev: 0.000000 (s)
# [2025-03-14 11:09:26,753][report][INFO] - 		+ stdev_: 0.00 (%)
# [2025-03-14 11:09:26,753][report][INFO] - + prefill:
# [2025-03-14 11:09:26,754][report][INFO] - 	+ memory:
# [2025-03-14 11:09:26,754][report][INFO] - 		+ max_ram: 1155.25 (MB)
# [2025-03-14 11:09:26,754][report][INFO] - 		+ max_global_vram: 14807.01 (MB)
# [2025-03-14 11:09:26,755][report][INFO] - 		+ max_process_vram: 4997.51 (MB)
# [2025-03-14 11:09:26,755][report][INFO] - 		+ max_reserved: 4473.23 (MB)
# [2025-03-14 11:09:26,756][report][INFO] - 		+ max_allocated: 4446.08 (MB)
# [2025-03-14 11:09:26,756][report][INFO] - 	+ latency:
# [2025-03-14 11:09:26,756][report][INFO] - 		+ count: 10
# [2025-03-14 11:09:26,757][report][INFO] - 		+ total: 0.483573 (s)
# [2025-03-14 11:09:26,757][report][INFO] - 		+ mean: 0.048357 (s)
# [2025-03-14 11:09:26,758][report][INFO] - 		+ p50: 0.045260 (s)
# [2025-03-14 11:09:26,758][report][INFO] - 		+ p90: 0.057673 (s)
# [2025-03-14 11:09:26,759][report][INFO] - 		+ p95: 0.063404 (s)
# [2025-03-14 11:09:26,762][report][INFO] - 		+ p99: 0.067989 (s)
# [2025-03-14 11:09:26,763][report][INFO] - 		+ stdev: 0.008255 (s)
# [2025-03-14 11:09:26,764][report][INFO] - 		+ stdev_: 17.07 (%)
# [2025-03-14 11:09:26,766][report][INFO] - 	+ throughput:
# [2025-03-14 11:09:26,768][report][INFO] - 		+ throughput: 41.36 (samples/s)
# [2025-03-14 11:09:26,769][report][INFO] - + decode:
# [2025-03-14 11:09:26,769][report][INFO] - 	+ memory:
# [2025-03-14 11:09:26,770][report][INFO] - 		+ max_ram: 1155.25 (MB)
# [2025-03-14 11:09:26,770][report][INFO] - 		+ max_global_vram: 14807.01 (MB)
# [2025-03-14 11:09:26,770][report][INFO] - 		+ max_process_vram: 4997.51 (MB)
# [2025-03-14 11:09:26,771][report][INFO] - 		+ max_reserved: 4473.23 (MB)
# [2025-03-14 11:09:26,771][report][INFO] - 		+ max_allocated: 4446.08 (MB)
# [2025-03-14 11:09:26,772][report][INFO] - 	+ latency:
# [2025-03-14 11:09:26,772][report][INFO] - 		+ count: 10
# [2025-03-14 11:09:26,772][report][INFO] - 		+ total: 30.848271 (s)
# [2025-03-14 11:09:26,773][report][INFO] - 		+ mean: 3.084827 (s)
# [2025-03-14 11:09:26,773][report][INFO] - 		+ p50: 2.949798 (s)
# [2025-03-14 11:09:26,774][report][INFO] - 		+ p90: 3.567158 (s)
# [2025-03-14 11:09:26,774][report][INFO] - 		+ p95: 3.672196 (s)
# [2025-03-14 11:09:26,774][report][INFO] - 		+ p99: 3.756226 (s)
# [2025-03-14 11:09:26,775][report][INFO] - 		+ stdev: 0.355008 (s)
# [2025-03-14 11:09:26,775][report][INFO] - 		+ stdev_: 11.51 (%)
# [2025-03-14 11:09:26,776][report][INFO] - 	+ throughput:
# [2025-03-14 11:09:26,776][report][INFO] - 		+ throughput: 64.19 (tokens/s)
# [2025-03-14 11:09:26,776][report][INFO] - + per_token:
# [2025-03-14 11:09:26,777][report][INFO] - 	+ latency:
# [2025-03-14 11:09:26,779][report][INFO] - 		+ count: 5490
# [2025-03-14 11:09:26,780][report][INFO] - 		+ total: 169.516835 (s)
# [2025-03-14 11:09:26,780][report][INFO] - 		+ mean: 0.030877 (s)
# [2025-03-14 11:09:26,781][report][INFO] - 		+ p50: 0.024308 (s)
# [2025-03-14 11:09:26,781][report][INFO] - 		+ p90: 0.050951 (s)
# [2025-03-14 11:09:26,789][report][INFO] - 		+ p95: 0.065629 (s)
# [2025-03-14 11:09:26,795][report][INFO] - 		+ p99: 0.102493 (s)
# [2025-03-14 11:09:26,796][report][INFO] - 		+ stdev: 0.016596 (s)
# [2025-03-14 11:09:26,798][report][INFO] - 		+ stdev_: 53.75 (%)
# Benchmark Results:
# {'load_model': {'memory': {'unit': 'MB', 'max_ram': 842.002432, 'max_global_vram': 14725.218304, 'max_process_vram': 4915.724288, 'max_reserved': 4401.922048, 'max_allocated': 4400.195072}, 'latency': {'unit': 's', 'values': [0.43676364135742185], 'count': 1, 'total': 0.43676364135742185, 'mean': 0.43676364135742185, 'p50': 0.43676364135742185, 'p90': 0.43676364135742185, 'p95': 0.43676364135742185, 'p99': 0.43676364135742185, 'stdev': 0, 'stdev_': 0}, 'throughput': None, 'energy': None, 'efficiency': None}, 'prefill': {'memory': {'unit': 'MB', 'max_ram': 1155.248128, 'max_global_vram': 14807.007232, 'max_process_vram': 4997.513216, 'max_reserved': 4473.225216, 'max_allocated': 4446.08}, 'latency': {'unit': 's', 'values': [0.0502988166809082, 0.04204079818725586, 0.04453376007080078, 0.0421638069152832, 0.06913513946533204, 0.05639987182617188, 0.045987007141113284, 0.042555233001708985, 0.041381855010986325, 0.04907657623291015], 'count': 10, 'total': 0.4835728645324708, 'mean': 0.04835728645324707, 'p50': 0.045260383605957036, 'p90': 0.05767339859008789, 'p95': 0.06340426902770994, 'p99': 0.06798896537780762, 'stdev': 0.008255328773351191, 'stdev_': 17.071530226024226}, 'throughput': {'unit': 'samples/s', 'value': 41.35881366986226}, 'energy': None, 'efficiency': None}, 'decode': {'memory': {'unit': 'MB', 'max_ram': 1155.248128, 'max_global_vram': 14807.007232, 'max_process_vram': 4997.513216, 'max_reserved': 4473.225216, 'max_allocated': 4446.08}, 'latency': {'unit': 's', 'values': [2.579564697265625, 2.89028564453125, 2.91388037109375, 3.05184130859375, 3.42418994140625, 3.7772333984375, 3.543816650390625, 2.8038427734375, 2.9857158203125, 2.87790087890625], 'count': 10, 'total': 30.848271484375, 'mean': 3.0848271484375003, 'p50': 2.949798095703125, 'p90': 3.5671583251953125, 'p95': 3.672195861816406, 'p99': 3.7562258911132815, 'stdev': 0.35500789374230546, 'stdev_': 11.508194030324226}, 'throughput': {'unit': 'tokens/s', 'value': 64.18511977252574}, 'energy': None, 'efficiency': None}, 'per_token': {'memory': None, 'latency': {'unit': 's', 'values': [0.020970495223999023, 0.022211584091186523, 0.022478847503662108, 0.036580352783203124, 0.02128998374938965, 0.022143999099731446, 0.022574079513549804, 0.025037824630737306, 0.031239168167114258, 0.028857343673706053, 0.024666112899780275, 0.03573657608032227, 0.03748454284667969, 0.07877324676513672, 0.06225920104980469, 0.040858623504638675, 0.026565631866455077, 0.10904576110839843, 0.05095116806030273, 0.026944511413574217, 0.028980224609375, 0.02352230453491211, 0.01817190361022949, 0.017573888778686524, 0.017705984115600586, 0.017733631134033204, 0.0190382080078125, 0.01762099266052246, 0.019150848388671874, 0.01904947280883789, 0.023207935333251953, 0.019506175994873046, 0.018354175567626953, 0.017670143127441407, 0.017477632522583008, 0.017515520095825195, 0.017574911117553712, 0.02048102378845215, 0.02106368064880371, 0.022156288146972656, 0.021824512481689453, 0.02263859176635742, 0.02285670471191406, 0.05030604934692383, 0.052261886596679685, 0.022435840606689454, 0.02372505569458008, 0.02367897605895996, 0.021398527145385742, 0.021337087631225587, 0.020156415939331054, 0.02049126434326172, 0.020156415939331054, 0.020970495223999023, 0.02068889617919922, 0.020734975814819336, 0.02088960075378418, 0.020521984100341797, 0.020727807998657227, 0.02082918357849121, 0.021444608688354492, 0.018111488342285157, 0.017721343994140625, 0.021601280212402343, 0.01884160041809082, 0.01903206443786621, 0.01882316780090332, 0.019126272201538085, 0.018486272811889647, 0.029642751693725586, 0.02933350372314453, 0.03322470474243164, 0.02852454376220703, 0.036176895141601564, 0.0312801284790039, 0.03885260772705078, 0.020983808517456053, 0.020256767272949217, 0.020213760375976563, 0.02144358444213867, 0.021766143798828123, 0.026702848434448243, 0.02105446434020996, 0.023006208419799806, 0.024597503662109374, 0.030688255310058594, 0.03451084899902344, 0.03561779022216797, 0.0256491527 ...

# %%
import json

def display_dict_nicely(d):
    print(json.dumps(d, indent=4))

# Example usage
your_dict = {'load_model': {'memory': {'unit': 'MB', 'max_ram': 842.002432, 'max_global_vram': 14725.218304, 'max_process_vram': 4915.724288, 'max_reserved': 4401.922048, 'max_allocated': 4400.195072}, 'latency': {'unit': 's', 'values': [0.43676364135742185], 'count': 1, 'total': 0.43676364135742185, 'mean': 0.43676364135742185, 'p50': 0.43676364135742185, 'p90': 0.43676364135742185, 'p95': 0.43676364135742185, 'p99': 0.43676364135742185, 'stdev': 0, 'stdev_': 0}, 'throughput': None, 'energy': None, 'efficiency': None}}

display_dict_nicely(your_dict)
# Out:
# {
#     "load_model": {
#         "memory": {
#             "unit": "MB",
#             "max_ram": 842.002432,
#             "max_global_vram": 14725.218304,
#             "max_process_vram": 4915.724288,
#             "max_reserved": 4401.922048,
#             "max_allocated": 4400.195072
#         },
#         "latency": {
#             "unit": "s",
#             "values": [
#                 0.43676364135742185
#             ],
#             "count": 1,
#             "total": 0.43676364135742185,
#             "mean": 0.43676364135742185,
#             "p50": 0.43676364135742185,
#             "p90": 0.43676364135742185,
#             "p95": 0.43676364135742185,
#             "p99": 0.43676364135742185,
#             "stdev": 0,
#             "stdev_": 0
#         },
#         "throughput": null,
#         "energy": null,
#         "efficiency": null
#     }
# }
